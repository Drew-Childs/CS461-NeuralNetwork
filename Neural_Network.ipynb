# %% [markdown]
# <a href="https://colab.research.google.com/github/Drew-Childs/CS461-NeuralNetwork/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras import models, layers
from keras.models import Sequential, load_model
from keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('processed_cleveland.csv')

df.drop(df.loc[df['ca']=='?'].index, inplace=True)
df.drop(df.loc[df['thal']=='?'].index, inplace=True)

X = pd.get_dummies(df.drop('num', axis = 1))
Y = df['num'].apply(lambda x: 1 if x > 0 else 0)

# %%
X_train, X_rem, Y_train, Y_rem = train_test_split(X, Y, train_size=0.8)
X_valid, X_test, Y_valid, Y_test = train_test_split(X_rem, Y_rem, test_size = 0.5)

# %%
model = Sequential()
model.add(Dense(units=8, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')
model.fit(X_train, Y_train, epochs=350, batch_size=10, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/350
# 24/24 [==============================] - 2s 23ms/step - loss: 2.7639 - accuracy: 0.5232 - val_loss: 0.6602 - val_accuracy: 0.6000
# Epoch 2/350
# 24/24 [==============================] - 0s 8ms/step - loss: 0.6917 - accuracy: 0.5274 - val_loss: 0.6614 - val_accuracy: 0.6000
# Epoch 3/350
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6868 - accuracy: 0.5316 - val_loss: 0.6717 - val_accuracy: 0.6000
# Epoch 4/350
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6844 - accuracy: 0.5359 - val_loss: 0.6712 - val_accuracy: 0.6000
# Epoch 5/350
# 24/24 [==============================] - 0s 10ms/step - loss: 0.6811 - accuracy: 0.5359 - val_loss: 0.6623 - val_accuracy: 0.6000
# Epoch 6/350
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5527 - val_loss: 0.6647 - val_accuracy: 0.6333
# Epoch 7/350
# ...

# %%
Y_hat = model.predict(X_valid)
Y_hat = [0 if val < 0.5 else 1 for val in Y_hat]

accuracy_score(Y_valid, Y_hat)
# Out:
# 1/1 [==============================] - 0s 95ms/step
# 0.8333333333333334
